# %% [markdown]
# # FIFA Project

# %%
import pandas as pd
#pd.set_option('display.max_columns',100)

# %%
fifa = pd.read_csv(r"C:\Users\VVRAVISH\Downloads\Pandas_project\fifa.csv")
fifa.head(3)
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
#
#    height_cm  weight_kg  nationality          club_name  \
# 0        169         67    Argentina       FC Barcelona
# 1        185         80     Portugal        Real Madrid
# 2        180         80  Netherlands  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# ...

# %%
fifa.shape
# Out:
# (16155, 81)

# %%
# we need to select few vcolumns only from total 81 columns
fifa.columns
# Out:
# Index(['height_cm', 'weight_kg', 'nationality', 'club_name', 'league_name',
#        'league_rank', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'player_positions', 'preferred_foot', 'international_reputation',
#        'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'team_position', 'team_jersey_number', 'nation_position',
#        'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic'],
#       dtype='object')

# %%
# selected columns are as under:
col_name = ['height_cm', 'weight_kg', 'nationality', 'club_name',
       'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
       'wage_eur', 'player_positions', 'preferred_foot',
       'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
       'body_type', 'real_face', 
       'team_position', 'team_jersey_number',
       'nation_position', 'nation_jersey_number',
       'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']

fifa[col_name]
fifa.head(3)
# Out:
#    height_cm  weight_kg  nationality          club_name  \
# 0        169         67    Argentina       FC Barcelona
# 1        185         80     Portugal        Real Madrid
# 2        180         80  Netherlands  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
#
#    weak_foot  skill_moves   work_rate body_type real_face team_position  \
# 0          3            4  Medium/Low    Normal       Yes            CF
# ...

# %%
# we need to drop the columns weak_foot and real_face
fifa.drop(columns= ['weak_foot','real_face'])
fifa.head(3)
# Out:
#    height_cm  weight_kg  nationality          club_name  \
# 0        169         67    Argentina       FC Barcelona
# 1        185         80     Portugal        Real Madrid
# 2        180         80  Netherlands  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
#
#    weak_foot  skill_moves   work_rate body_type real_face team_position  \
# 0          3            4  Medium/Low    Normal       Yes            CF
# ...

# %%
# we need to find the plyers whos shooting is > than passing
fifa.query("shooting > passing")
fifa.head(3)
# Out:
#    height_cm  weight_kg  nationality          club_name  \
# 0        169         67    Argentina       FC Barcelona
# 1        185         80     Portugal        Real Madrid
# 2        180         80  Netherlands  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
#
#    weak_foot  skill_moves   work_rate body_type real_face team_position  \
# 0          3            4  Medium/Low    Normal       Yes            CF
# ...
